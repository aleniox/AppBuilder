# %%
import openai

client = openai.OpenAI(
    base_url="http://localhost:8080/v1", 
    api_key="sk-no-key-required"
)

completion = client.chat.completions.create(
    model="your-video-model",
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "Video này nói về nội dung gì vậy?"},
                {
                    "type": "input_video",
                    "input_video": {
                        # Phải có file:// và đường dẫn này nằm trong phạm vi của --media-path
                        "url": "file:///C:/Users/PC/Downloads/output_3417ccd4.mp4" 
                    }
                }
            ]
        }
    ]
)

print(completion.choices[0].message.content)
# Out:
# Running cells with 'video-editor (3.12.9) (Python 3.12.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'f:/WebEdit/video-editor/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
